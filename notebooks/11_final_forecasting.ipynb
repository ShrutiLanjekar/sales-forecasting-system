# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

import joblib

# %%
df = pd.read_csv(
    "../data/processed/feature_engineered.csv"
)

df['Date'] = pd.to_datetime(df['Date'])

# %%
df = df.sort_values(
    ['State', 'Date']
)

# %%
features = [
    'lag_1',
    'lag_7',
    'lag_30',
    'rolling_mean_7',
    'rolling_mean_30',
    'rolling_std_7',
    'day_of_week',
    'month',
    'quarter',
    'week_of_year',
    'year',
    'is_holiday'
]

# %%
from xgboost import XGBRegressor

# %%
model = XGBRegressor(
    objective='reg:squarederror',
    n_estimators=200,
    learning_rate=0.05,
    max_depth=6,
    random_state=42
)

# %%
X = df[features]

y = df['Sales']

model.fit(X, y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=200,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
joblib.dump(
    model,
    "../models/final_forecasting_model.pkl"
)
# Out:
# ['../models/final_forecasting_model.pkl']

# %%
future_dates = pd.date_range(
    start=df['Date'].max() + pd.Timedelta(days=1),
    periods=56
)

# %%
future_df = pd.DataFrame({
    'Date': future_dates
})

# %%
future_df['day_of_week'] = future_df['Date'].dt.dayofweek

future_df['month'] = future_df['Date'].dt.month

future_df['quarter'] = future_df['Date'].dt.quarter

future_df['week_of_year'] = (
    future_df['Date']
    .dt.isocalendar()
    .week
    .astype(int)
)

future_df['year'] = future_df['Date'].dt.year

# %%
last_row = df.iloc[-1]


future_df['lag_1'] = last_row['lag_1']

future_df['lag_7'] = last_row['lag_7']

future_df['lag_30'] = last_row['lag_30']

future_df['rolling_mean_7'] = last_row['rolling_mean_7']

future_df['rolling_mean_30'] = last_row['rolling_mean_30']

future_df['rolling_std_7'] = last_row['rolling_std_7']

future_df['is_holiday'] = 0

# %%
future_predictions = model.predict(
    future_df[features]
)

# %%
future_df['Forecasted_Sales'] = future_predictions

# %%
future_df.to_csv(
    "../outputs/final_8week_forecast.csv",
    index=False
)

# %%
plt.figure(figsize=(15,6))

plt.plot(
    future_df['Date'],
    future_df['Forecasted_Sales']
)

plt.title("Next 8 Weeks Sales Forecast")

plt.xlabel("Date")

plt.ylabel("Forecasted Sales")

plt.grid(True)

plt.show()
