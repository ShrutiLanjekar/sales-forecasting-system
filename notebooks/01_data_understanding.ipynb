# %%
import pandas as pd

# Load dataset
df = pd.read_excel(r"D:\forecasting_system\data\raw\Forecasting Case- Study.xlsx")

# %%
# First 5 rows
print(df.head())
# Out:
#         State                 Date        Total   Category
# 0     Alabama  2019-01-12 00:00:00  109574036.0  Beverages
# 1     Arizona  2019-01-12 00:00:00  109101594.6  Beverages
# 2    Arkansas  2019-01-12 00:00:00   58049432.2  Beverages
# 3  California  2019-01-12 00:00:00  444766890.6  Beverages
# 4    Colorado  2019-01-12 00:00:00   89816716.3  Beverages

# %%
# Dataset info
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8084 entries, 0 to 8083
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   State     8084 non-null   str
#  1   Date      8084 non-null   object
#  2   Total     8084 non-null   float64
#  3   Category  8084 non-null   str
# dtypes: float64(1), object(1), str(2)
# memory usage: 252.8+ KB
# None

# %%
# Missing values
print(df.isnull().sum())
# Out:
# State       0
# Date        0
# Total       0
# Category    0
# dtype: int64

# %%
# Shape
print(df.shape)
# Out:
# (8084, 4)

# %%
# Columns
print(df.columns)
# Out:
# Index(['State', 'Date', 'Total', 'Category'], dtype='str')

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
df['Date'] = pd.to_datetime(df['Date'])
print(df.dtypes)
# Out:
# State                  str
# Date        datetime64[us]
# Total              float64
# Category               str
# dtype: object

# %%
df = df.sort_values(['State', 'Date'])

# %%
print(df['Date'].min())
print(df['Date'].max())
# Out:
# 2019-01-12 00:00:00
# 2023-12-03 00:00:00

# %%
print(df.groupby('State')['Date'].count())
# Out:
# State
# Alabama           188
# Arizona           188
# Arkansas          188
# California        188
# Colorado          188
# Connecticut       188
# Florida           188
# Georgia           188
# Illinois          188
# Indiana           188
# Iowa              188
# Kansas            188
# Kentucky          188
# Louisiana         188
# Maine             188
# Maryland          188
# Massachusetts     188
# Michigan          188
# Minnesota         188
# Mississippi       188
# Missouri          188
# Nebraska          188
# Nevada            188
# New Hampshire     188
# New Mexico        188
# New York          188
# North Carolina    188
# Ohio              188
# Oklahoma          188
# Oregon            188
# Pennsylvania      188
# Rhode Island      188
# South Carolina    188
# South Dakota      188
# Tennessee         188
# Texas             188
# Utah              188
# Vermont           188
# Virginia          188
# Washington        188
# West Virginia     188
# ...

# %%
import os

print(os.getcwd())
# Out:
# d:\forecasting_system\notebooks

# %%
df.to_csv(r"D:\forecasting_system\data\processed\initial_clean.csv", index=False)
